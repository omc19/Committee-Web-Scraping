# %%
#import requests
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
# Set the URL you want to webscrape from
url = 'http://websites.sportstg.com/assoc_page.cgi?c=0-5959-0-531590-0&a=COMPS'

response = requests.get(url)

# Parse HTML and save to BeautifulSoup object¶
soup = BeautifulSoup(response.text, "html.parser")
print(soup)
# Out:
# <!DOCTYPE doctype html>
#
# <!--[if lt IE 7 ]> <html lang="en" class="no-js ie6"> <![endif]-->
# <!--[if IE 7 ]> <html lang="en" class="no-js ie7"> <![endif]-->
# <!--[if IE 8 ]> <html lang="en" class="no-js ie8"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!--> <html class="no-js" lang="en"> <!--<![endif]-->
# <head>
# <script>
#            if ((Math.floor(Math.random() * 10) + 1) == 1){
#                var _prum = [['id', '533de351abe53d8c3a7b23c6'],
#                             ['mark', 'firstbyte', (new Date()).getTime()]];
#                (function() {
#                    var s = document.getElementsByTagName('script')[0]
#                        , p = document.createElement('script');
#                    p.async = 'async';
#                    p.src = '//rum-static.pingdom.net/prum.min.js';
#                    s.parentNode.insertBefore(p, s);
#                })();
#            }
#            </script>
# ...

# %%
points_table_list = []
all_a_tags = soup.findAll('a')
print(all_a_tags)
# Out:
# [<a href="http://websites.sportstg.com" target="_parent"></a>, <a class="sup-link" href="http://support.sportstg.com/" target="_parent">Support</a>, <a class="ppl-link" href="https://passport.sportstg.com//login/?&amp;e=1%3A5959&amp;sp=23&amp;cy=New%20Zealand&amp;st=Canterbury&amp;tt=&amp;pa=login&amp;en=Canterbury%20Hockey%20Association&amp;url=http%3A%2F%2Fwebsites.sportstg.com%2Fassoc_page.cgi%3Fc%3D0-5959-0-531590-0%3Ba%3DCOMPS&amp;apk=AJM6n0eKVdq3s9m7cxtSOH8wZQRFUi-stg" target="_parent">Passport</a>, <a class="ppn-link" href="https://passport.sportstg.com//account/?" target="_parent"><span id="SPPassportName"></span></a>, <a class="sup-link" href="http://support.sportstg.com/" target="_parent">Support</a>, <a class="so-link" href="https://passport.sportstg.com//logout/?" target="_parent">Sign out</a>, <a href="assoc_page.cgi?c=0-5959-0-531590-0&amp;sID=224304">Web Site</a>, <a href="assoc_page.cgi?c=0-5959-0-531590-0&amp;a=CLUBS">Club Websites</a>, <a href="assoc_page.cgi?c=0-59
# ...

# %%
links = soup.findAll('a', attrs={'class': 'ladder-link'})
print(soup.findAll('a', attrs={'class': 'ladder-link'}))
# Out:
# [<a class="ladder-link" href="comp_info.cgi?a=LADDER&amp;compID=525377&amp;c=0-5959-0-531590-0">Points Table</a>, <a class="ladder-link" href="comp_info.cgi?a=LADDER&amp;compID=526294&amp;c=0-5959-0-531590-0">Points Table</a>, <a class="ladder-link" href="comp_info.cgi?a=LADDER&amp;compID=528776&amp;c=0-5959-0-531590-0">Points Table</a>, <a class="ladder-link" href="comp_info.cgi?a=LADDER&amp;compID=528769&amp;c=0-5959-0-531590-0">Points Table</a>, <a class="ladder-link" href="comp_info.cgi?a=LADDER&amp;compID=533320&amp;c=0-5959-0-531590-0">Points Table</a>, <a class="ladder-link" href="comp_info.cgi?a=LADDER&amp;compID=533319&amp;c=0-5959-0-531590-0">Points Table</a>, <a class="ladder-link" href="comp_info.cgi?a=LADDER&amp;compID=528779&amp;c=0-5959-0-531590-0">Points Table</a>, <a class="ladder-link" href="comp_info.cgi?a=LADDER&amp;compID=528774&amp;c=0-5959-0-531590-0">Points Table</a>, <a class="ladder-link" href="comp_info.cgi?a=LADDER&amp;compID=528778&amp;c=0-5959-0-531590-0
# ...

# %%
link_list = []
for link in links:
    print(link['href'])
    link_list.append(link['href'])
# Out:
# comp_info.cgi?a=LADDER&compID=525377&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=526294&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=528776&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=528769&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=533320&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=533319&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=528779&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=528774&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=528778&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=528772&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=528783&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=528773&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=522441&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=525104&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=522866&c=0-5959-0-531590-0
# comp_info.cgi?a=LADDER&compID=525105&c=0-5959-0-531590-0
# ...

# %%
full_links = []
for one_link in link_list:
    url_link = 'http://websites.sportstg.com/' + one_link
    print(url_link)
    full_links.append(url_link)
    
print('next list')
# Out:
# http://websites.sportstg.com/comp_info.cgi?a=LADDER&compID=525377&c=0-5959-0-531590-0
# http://websites.sportstg.com/comp_info.cgi?a=LADDER&compID=526294&c=0-5959-0-531590-0
# http://websites.sportstg.com/comp_info.cgi?a=LADDER&compID=528776&c=0-5959-0-531590-0
# http://websites.sportstg.com/comp_info.cgi?a=LADDER&compID=528769&c=0-5959-0-531590-0
# http://websites.sportstg.com/comp_info.cgi?a=LADDER&compID=533320&c=0-5959-0-531590-0
# http://websites.sportstg.com/comp_info.cgi?a=LADDER&compID=533319&c=0-5959-0-531590-0
# http://websites.sportstg.com/comp_info.cgi?a=LADDER&compID=528779&c=0-5959-0-531590-0
# http://websites.sportstg.com/comp_info.cgi?a=LADDER&compID=528774&c=0-5959-0-531590-0
# http://websites.sportstg.com/comp_info.cgi?a=LADDER&compID=528778&c=0-5959-0-531590-0
# http://websites.sportstg.com/comp_info.cgi?a=LADDER&compID=528772&c=0-5959-0-531590-0
# http://websites.sportstg.com/comp_info.cgi?a=LADDER&compID=528783&c=0-5959-0-531590-0
# ...

# %%
#for i in range(0,len(full_links)-1):
#     response1 = requests.get(full_links[i])

#     # Parse HTML and save to BeautifulSoup object¶

#     soup1 = BeautifulSoup(response1.text, "html.parser")

#     print(soup1)


response1 = requests.get(full_links[0])

# Parse HTML and save to BeautifulSoup object¶

soup1 = BeautifulSoup(response1.text, "html.parser")

print(soup1)
print(soup1.findAll('table', attrs={'class': 'tableClass'}))
table = soup1.findAll('table', attrs={'class': 'tableClass'})
print('##############################################')

# try:
#     print(soup1.findAll('a', attrs={'class':'buttons nonactive'}))
#     print('yeah')
#     pool = soup1.findAll('a', attrs={'class':'buttons nonactive'})
#     print(pool)
#     print(pool[0]['href'])
#     href = pool[0]['href']
# except:
#     print('not in')
# Out:
# <!DOCTYPE doctype html>
#
# <!--[if lt IE 7 ]> <html lang="en" class="no-js ie6"> <![endif]-->
# <!--[if IE 7 ]> <html lang="en" class="no-js ie7"> <![endif]-->
# <!--[if IE 8 ]> <html lang="en" class="no-js ie8"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!--> <html class="no-js" lang="en"> <!--<![endif]-->
# <head>
# <script>
#            if ((Math.floor(Math.random() * 10) + 1) == 1){
#                var _prum = [['id', '533de351abe53d8c3a7b23c6'],
#                             ['mark', 'firstbyte', (new Date()).getTime()]];
#                (function() {
#                    var s = document.getElementsByTagName('script')[0]
#                        , p = document.createElement('script');
#                    p.async = 'async';
#                    p.src = '//rum-static.pingdom.net/prum.min.js';
#                    s.parentNode.insertBefore(p, s);
#                })();
#            }
#            </script>
# ...

# %%
print(table[0])
print(table[0].text.strip())
text_table = table[0].text.strip()
# Out:
# <table class="tableClass">
# <caption class="tableTitle">
# <h4> Current Points Table </h4>
# </caption>
# <tr>
# <th class="ladder-pos-col">POS</th>
# <th class="ladder-team-col">TEAM</th>
# <th class="ladder-num">P</th>
# <th class="ladder-num">W</th>
# <th class="ladder-num">L</th>
# <th class="ladder-num">D</th>
# <th class="ladder-num">B</th>
# <th class="ladder-num">PP</th>
# <th class="ladder-num">F</th>
# <th class="ladder-num">A</th>
# <th class="ladder-num">GD</th>
# <th class="ladder-num">PTS</th>
# </tr>
# <tr class="odd">
# <td class="ladder-pos-col">1</td>
# <td class="ladder-team-col"><a href="http://websites.sportstg.com/team_info.cgi?id=26453559&amp;client=0-5959-0-525377-0&amp;compID=525377" target="spsubwindow">Southern United Div 1</a></td>
# <td class="ladder-num">18</td>
# <td class="ladder-num">15</td>
# <td class="ladder-num">1</td>
# <td class="ladder-num">2</td>
# <td class="ladder-num">0</td>
# <td class="ladder-num">0</td>
# <td class="ladder-num">98</td>
# ...

# %%
print(text_table.split())
split_table = text_table.split()
# Out:
# ['Current', 'Points', 'Table', 'POS', 'TEAM', 'P', 'W', 'L', 'D', 'B', 'PP', 'F', 'A', 'GD', 'PTS', '1', 'Southern', 'United', 'Div', '1', '18', '15', '1', '2', '0', '0', '98', '36', '62', '47', '2', 'HSOB/Burnside', 'MWO', '18', '14', '2', '2', '0', '0', '70', '23', '47', '44', '3', 'University', 'Mongols', '18', '12', '3', '3', '0', '0', '60', '29', '31', '39', '4', 'Carlton', 'Redcliffs', 'MWO', '18', '8', '6', '4', '0', '0', '50', '43', '7', '28', '5', 'Harewood', 'White', '18', '8', '6', '4', '0', '0', '47', '41', '6', '28', '6', 'University', 'Alumni', '18', '5', '9', '4', '0', '0', '39', '51', '-12', '19', '7', 'Avon', 'Blue', '18', '5', '9', '4', '0', '0', '41', '62', '-21', '19', '8', 'Hornby', 'Coyotes', '18', '4', '11', '3', '0', '0', '33', '71', '-38', '15', '9', 'Hinemoa-Kaiapoi', 'Kauri', '18', '3', '14', '1', '0', '0', '35', '70', '-35', '10', '10', 'Harewood', 'Red', '18', '2', '15', '1', '0', '0', '27', '74', '-47', '7']

# %%
#Don't think this does anything
new_list = []
count = 0
#'here'.toInt()
for i in split_table:
    try:
        x = int(i)
        print('yeet')
        count+=1
        new_list.append(x)
    except ValueError:
        print('happen')
        
print(new_list)
print(count)
# Out:
# happen
# happen
# happen
# happen
# happen
# happen
# happen
# happen
# happen
# happen
# happen
# happen
# happen
# happen
# happen
# yeet
# happen
# happen
# happen
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# happen
# happen
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# happen
# happen
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# happen
# happen
# happen
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# happen
# happen
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# happen
# happen
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# happen
# happen
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# happen
# happen
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# happen
# happen
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# yeet
# ...

# %%
count = 0
index_list = [] #index of university in the table
for i in split_table:
    if i == 'University':
        index_list.append(count)
        count += 1
    else:
        count += 1
    
        
print(index_list)
# Out:
# [44, 84]

# %%
start_of_played = []
#split_table[30].isalpha()
for i in index_list:
    if split_table[i+1].isalpha(): #seeing if there is a name next to University e.g. Vikings
        start_of_played.append(i+1)

print(start_of_played)
# Out:
# [45, 85]

# %%
goals = []
for i in start_of_played: #find the "For" column which represents goals
    goals.append(split_table[i+7])
print(goals)
int_goals = []
for i in goals:
    int_goals.append(int(i))

print(int_goals)
# Out:
# ['60', '39']
# [60, 39]

# %%
total = sum(int_goals)
print(total)
# Out:
# 99

# %%
try:
    print(soup1.findAll('a', attrs={'class':'buttons nonactive'}))
    print('yeah')
    pool = soup1.findAll('a', attrs={'class':'buttons nonactive'})
    print(pool)
    print(pool[0]['href'])
    href = pool[0]['href']
    #new call
    new_url = 'http://websites.sportstg.com/' + href
    response2 = requests.get(new_url)

    # Parse HTML and save to BeautifulSoup object¶
    soup2 = BeautifulSoup(response2.text, "html.parser")
    print(soup2)
    table2 = soup2.findAll('table', attrs={'class': 'tableClass'})
    
    print(table2[0])
    print(table2[0].text.strip())
    text_table2 = table2[0].text.strip()
    
    print(text_table2.split())
    split_table2 = text_table2.split()
    
    new_list2 = []
    count2 = 0
    #'here'.toInt()
#     for i in split_table2:
#         try:
#             x = int(i)
#             print('yeet')
#             count2+=1
#             new_list2.append(x)
#         except ValueError:
#             print('happen')

#     print(new_list2)
#     print(count2)
    
    #index + 1 + another
    
    count2 = 0
    index_list2 = [] #index of university in the table
    for i in split_table2:
        if i == 'University':
            index_list2.append(count2)
            count2 += 1
        else:
            count2 += 1
        
    print(index_list2)
    print(split_table2[16],split_table2[17])
    print(split_table2[96],split_table2[97])
    print(split_table2[122],split_table2[123])


    start_of_played2 = []
    #split_table2 [30].isalpha()
    for i in index_list2:
        if split_table2[i+1].isalpha(): #seeing if there is a name next to University e.g. Vikings
            start_of_played2.append(i+1)

    print(start_of_played2)
    
    goals2 = []
    for i in start_of_played2: #find the "For" column which represents goals
        goals2.append(split_table2[i+7])
    print(goals2)
    int_goals2 = [] #turn goals from string to ints
    for i in goals2:
        int_goals2.append(int(i))

    print("goals")
    print(int_goals2)
    
    total2 = sum(int_goals2)
    print(total2)
    
except:
    print('not in')
# Out:
# [<a class="buttons nonactive" href="comp_info.cgi?client=0-5959-0-525377-0&amp;pool=1&amp;action=LADDER&amp;round=0">Division 1 Round Robin </a>, <a class="buttons nonactive" href="comp_info.cgi?client=0-5959-0-525377-0&amp;pool=2&amp;action=LADDER&amp;round=0">Division 2 Round Robin</a>]
# yeah
# [<a class="buttons nonactive" href="comp_info.cgi?client=0-5959-0-525377-0&amp;pool=1&amp;action=LADDER&amp;round=0">Division 1 Round Robin </a>, <a class="buttons nonactive" href="comp_info.cgi?client=0-5959-0-525377-0&amp;pool=2&amp;action=LADDER&amp;round=0">Division 2 Round Robin</a>]
# comp_info.cgi?client=0-5959-0-525377-0&pool=1&action=LADDER&round=0
# <!DOCTYPE doctype html>
#
# <!--[if lt IE 7 ]> <html lang="en" class="no-js ie6"> <![endif]-->
# <!--[if IE 7 ]> <html lang="en" class="no-js ie7"> <![endif]-->
# <!--[if IE 8 ]> <html lang="en" class="no-js ie8"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!--> <html class="no-js" lang="en"> <!--<![endif]-->
# <head>
# <script>
# ...
